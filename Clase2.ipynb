# %% [markdown]
# # Clase2

# %%
from pylab import *
# %matplotlib inline

# %%
def fun (x):
    #tab tab tab importantes
    y = x**2
    return y

# %%
linspace(0,6)# siempre te dara 50 valores, dividiendo el rango que tengas 
# linspace(0,2,5) el ultimo valor es para definir cuantos valores quieres en este caso tendriamos solo 5
# Out:
# array([ 0.        ,  0.12244898,  0.24489796,  0.36734694,  0.48979592,
#         0.6122449 ,  0.73469388,  0.85714286,  0.97959184,  1.10204082,
#         1.2244898 ,  1.34693878,  1.46938776,  1.59183673,  1.71428571,
#         1.83673469,  1.95918367,  2.08163265,  2.20408163,  2.32653061,
#         2.44897959,  2.57142857,  2.69387755,  2.81632653,  2.93877551,
#         3.06122449,  3.18367347,  3.30612245,  3.42857143,  3.55102041,
#         3.67346939,  3.79591837,  3.91836735,  4.04081633,  4.16326531,
#         4.28571429,  4.40816327,  4.53061224,  4.65306122,  4.7755102 ,
#         4.89795918,  5.02040816,  5.14285714,  5.26530612,  5.3877551 ,
#         5.51020408,  5.63265306,  5.75510204,  5.87755102,  6.        ])

# %%
x=linspace(0,6)
plot(x,fun(x))

# %%
def fun2 (x):
    #tab tab tab importantes
    y = x**3
    return y

# %%
a= "Hola"
def hola():
    a="!!!HOLA!!!"
    print a
print a
hola()
# Out:
# Hola
# !!!HOLA!!!

# %%
plot (x,fun(x),x,fun2(x))
xlim(0,1)
ylim(0,1)
# Out:
# (0, 1)

# %%
def fun3 (a):
    #tab tab tab importantes
    x = linspace(0,a)
    y = x**3
    plot (x,y)

# %%
fun3(1)

# %%
puntosy = [1,2,3,4,5,0,2]
puntosx = [0,1,2,3,4,5,6]
plot(puntosx,puntosy,'o')
#show() para separar graficas  
plot (x,fun(x))

# %%
def fun4 ((x),exponente):
    return x**exponente

# %%
for i in range(3):
    y=fun4(x,i)
    plot(x,y)

# %%
#range(4) 
#arange (0,2.5,0.5) saca un array

# %%
platillos[100,30,130]

# %%
def cuenta(platillos,propina):
    total = 0 
    for i in range(len(platillos)):
        total = total + platillos[i]
        
    total = total + total*propina
    print total

# %%
#platillos = [50,24,56,76,12,2]
#propina =0.15
cuenta([40,30,12],0.15)
# Out:
# 94.3
